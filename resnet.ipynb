# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter
from torchvision.models import resnet34
import numpy as np

# %%
# CutMix数据增强
def cutmix_data(x, y, alpha=1.0):
    indices = torch.randperm(x.size(0))
    shuffled_x = x[indices]
    shuffled_y = y[indices]
    lam = np.random.beta(alpha, alpha)

    bbx1, bby1, bbx2, bby2 = rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bbx2] = shuffled_x[:, :, bbx1:bbx2, bby1:bbx2]

    return x, y, shuffled_y, lam

def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# 数据预处理
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4865, 0.4409), (0.2673, 0.2564, 0.2762)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4865, 0.4409), (0.2673, 0.2564, 0.2762)),
])

# 加载数据集
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 定义ResNet-34模型
class ResNetCIFAR(nn.Module):
    def __init__(self):
        super(ResNetCIFAR, self).__init__()
        self.model = resnet34(weights=None)
        self.model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.model.maxpool = nn.Identity()
        self.model.fc = nn.Linear(512, 100)

    def forward(self, x):
        return self.model(x)

# %%
net = ResNetCIFAR()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = net.to(device)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# 初始化TensorBoard
writer = SummaryWriter('resnet/experiment_resnet34')

# 记录最高准确率
best_acc = 0

# %%
# 训练模型
for epoch in range(100):  # 共训练100个epoch
    net.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # 应用CutMix
        inputs, targets_a, targets_b, lam = cutmix_data(inputs, labels)

        optimizer.zero_grad()
        outputs = net(inputs)
        loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (lam * (predicted == targets_a).sum().item() + (1 - lam) * (predicted == targets_b).sum().item())

    train_loss = running_loss / len(trainloader)
    train_accuracy = 100 * correct / total

    writer.add_scalar('training loss', train_loss, epoch)
    writer.add_scalar('training accuracy', train_accuracy, epoch)


    scheduler.step()

    # 验证模型
    net.eval()
    correct = 0
    total = 0
    val_loss = 0.0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss /= len(testloader)
    val_accuracy = 100 * correct / total

    writer.add_scalar('validation loss', val_loss, epoch)
    writer.add_scalar('validation accuracy', val_accuracy, epoch)

    print(f'Epoch {epoch + 1}: Training Loss: {train_loss:.3f}, Training Accuracy: {train_accuracy:.2f}%, Validation Loss: {val_loss:.3f}, Validation Accuracy: {val_accuracy:.2f}%')

    # 保存验证集上最高准确率的模型
    if val_accuracy > best_acc:
        best_acc = val_accuracy
        torch.save(net.state_dict(), 'resnet34.pth')

writer.close()
# Out:
# /root/miniconda3/lib/python3.12/site-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 1: Training Loss: 4.363, Training Accuracy: 5.13%, Validation Loss: 3.720, Validation Accuracy: 11.49%
# Epoch 2: Training Loss: 4.140, Training Accuracy: 8.12%, Validation Loss: 3.419, Validation Accuracy: 17.54%
# Epoch 3: Training Loss: 3.938, Training Accuracy: 11.96%, Validation Loss: 3.066, Validation Accuracy: 25.24%
# Epoch 4: Training Loss: 3.751, Training Accuracy: 15.49%, Validation Loss: 2.817, Validation Accuracy: 28.65%
# Epoch 5: Training Loss: 3.655, Training Accuracy: 17.46%, Validation Loss: 2.587, Validation Accuracy: 34.50%
# Epoch 6: Training Loss: 3.564, Training Accuracy: 20.40%, Validation Loss: 2.477, Validation Accuracy: 37.00%
# Epoch 7: Training Loss: 3.396, Training Accuracy: 23.63%, Validation Loss: 2.231, Validation Accuracy: 42.37%
# Epoch 8: Training Loss: 3.299, Training Accuracy: 26.07%, Validation Loss: 2.066, Validation Accuracy: 46.77%
# Epoch 9: Training Loss: 3.295, Training Accuracy: 26.41%, Validation Loss: 2.087, Validation Accuracy: 48.21%
# Epoch 10: Training Loss: 3.199, Training Accuracy: 28.25%, Validation Loss: 1.923, Validation Accuracy: 51.78%
# Epoch 11: Training Loss: 3.093, Training Accuracy: 30.11%, Validation Loss: 1.873, Validation Accuracy: 52.04%
# Epoch 12: Training Loss: 3.005, Training Accuracy: 31.88%, Validation Loss: 1.769, Validation Accuracy: 54.02%
# Epoch 13: Training Loss: 3.029, Training Accuracy: 32.69%, Validation Loss: 1.785, Validation Accuracy: 56.64%
# Epoch 14: Training Loss: 2.948, Training Accuracy: 32.86%, Validation Loss: 1.794, Validation Accuracy: 54.95%
# Epoch 15: Training Loss: 2.910, Training Accuracy: 34.13%, Validation Loss: 1.599, Validation Accuracy: 57.50%
# Epoch 16: Training Loss: 2.882, Training Accuracy: 34.71%, Validation Loss: 1.586, Validation Accuracy: 59.32%
# Epoch 17: Training Loss: 2.756, Training Accuracy: 38.11%, Validation Loss: 1.483, Validation Accuracy: 62.09%
# Epoch 18: Training Loss: 2.819, Training Accuracy: 36.60%, Validation Loss: 1.637, Validation Accuracy: 59.32%
# Epoch 19: Training Loss: 2.712, Training Accuracy: 38.70%, Validation Loss: 1.486, Validation Accuracy: 61.86%
# Epoch 20: Training Loss: 2.703, Training Accuracy: 38.85%, Validation Loss: 1.440, Validation Accuracy: 63.47%
# Epoch 21: Training Loss: 2.683, Training Accuracy: 39.74%, Validation Loss: 1.435, Validation Accuracy: 63.28%
# Epoch 22: Training Loss: 2.630, Training Accuracy: 40.60%, Validation Loss: 1.359, Validation Accuracy: 65.80%
# Epoch 23: Training Loss: 2.576, Training Accuracy: 41.54%, Validation Loss: 1.377, Validation Accuracy: 65.43%
# Epoch 24: Training Loss: 2.586, Training Accuracy: 40.92%, Validation Loss: 1.336, Validation Accuracy: 65.70%
# Epoch 25: Training Loss: 2.544, Training Accuracy: 41.92%, Validation Loss: 1.376, Validation Accuracy: 65.86%
# Epoch 26: Training Loss: 2.508, Training Accuracy: 43.56%, Validation Loss: 1.272, Validation Accuracy: 67.17%
# Epoch 27: Training Loss: 2.503, Training Accuracy: 43.52%, Validation Loss: 1.289, Validation Accuracy: 67.68%
# Epoch 28: Training Loss: 2.461, Training Accuracy: 44.07%, Validation Loss: 1.244, Validation Accuracy: 68.51%
# Epoch 29: Training Loss: 2.494, Training Accuracy: 43.70%, Validation Loss: 1.413, Validation Accuracy: 68.16%
# Epoch 30: Training Loss: 2.472, Training Accuracy: 43.37%, Validation Loss: 1.385, Validation Accuracy: 67.90%
# Epoch 31: Training Loss: 2.315, Training Accuracy: 47.43%, Validation Loss: 1.094, Validation Accuracy: 72.71%
# Epoch 32: Training Loss: 2.275, Training Accuracy: 46.86%, Validation Loss: 1.072, Validation Accuracy: 72.95%
# Epoch 33: Training Loss: 2.183, Training Accuracy: 49.62%, Validation Loss: 1.056, Validation Accuracy: 72.93%
# Epoch 34: Training Loss: 2.212, Training Accuracy: 48.80%, Validation Loss: 1.083, Validation Accuracy: 73.14%
# Epoch 35: Training Loss: 2.149, Training Accuracy: 50.08%, Validation Loss: 1.082, Validation Accuracy: 73.11%
# Epoch 36: Training Loss: 2.197, Training Accuracy: 49.03%, Validation Loss: 1.012, Validation Accuracy: 73.41%
# Epoch 37: Training Loss: 2.183, Training Accuracy: 51.38%, Validation Loss: 1.062, Validation Accuracy: 73.52%
# Epoch 38: Training Loss: 2.237, Training Accuracy: 49.41%, Validation Loss: 1.024, Validation Accuracy: 73.85%
# Epoch 39: Training Loss: 2.122, Training Accuracy: 51.21%, Validation Loss: 1.038, Validation Accuracy: 73.92%
# Epoch 40: Training Loss: 2.120, Training Accuracy: 50.88%, Validation Loss: 1.044, Validation Accuracy: 73.88%
# Epoch 41: Training Loss: 2.133, Training Accuracy: 50.89%, Validation Loss: 1.076, Validation Accuracy: 73.63%
# Epoch 42: Training Loss: 2.128, Training Accuracy: 51.18%, Validation Loss: 1.042, Validation Accuracy: 74.29%
# Epoch 43: Training Loss: 2.174, Training Accuracy: 49.47%, Validation Loss: 1.028, Validation Accuracy: 73.98%
# Epoch 44: Training Loss: 2.163, Training Accuracy: 50.28%, Validation Loss: 1.029, Validation Accuracy: 74.11%
# Epoch 45: Training Loss: 2.084, Training Accuracy: 52.71%, Validation Loss: 1.011, Validation Accuracy: 74.17%
# Epoch 46: Training Loss: 2.094, Training Accuracy: 52.09%, Validation Loss: 1.023, Validation Accuracy: 74.44%
# Epoch 47: Training Loss: 2.077, Training Accuracy: 52.67%, Validation Loss: 1.028, Validation Accuracy: 74.31%
# Epoch 48: Training Loss: 2.121, Training Accuracy: 51.28%, Validation Loss: 1.026, Validation Accuracy: 74.39%
# Epoch 49: Training Loss: 2.088, Training Accuracy: 52.65%, Validation Loss: 0.993, Validation Accuracy: 74.50%
# Epoch 50: Training Loss: 2.098, Training Accuracy: 50.73%, Validation Loss: 0.997, Validation Accuracy: 74.66%
# Epoch 51: Training Loss: 2.121, Training Accuracy: 51.29%, Validation Loss: 0.999, Validation Accuracy: 74.36%
# Epoch 52: Training Loss: 2.092, Training Accuracy: 51.30%, Validation Loss: 1.008, Validation Accuracy: 74.36%
# Epoch 53: Training Loss: 2.116, Training Accuracy: 51.30%, Validation Loss: 1.009, Validation Accuracy: 74.86%
# Epoch 54: Training Loss: 2.070, Training Accuracy: 52.84%, Validation Loss: 1.043, Validation Accuracy: 74.57%
# Epoch 55: Training Loss: 2.059, Training Accuracy: 52.35%, Validation Loss: 1.011, Validation Accuracy: 74.71%
# Epoch 56: Training Loss: 2.069, Training Accuracy: 52.67%, Validation Loss: 0.995, Validation Accuracy: 75.05%
# Epoch 57: Training Loss: 2.066, Training Accuracy: 52.39%, Validation Loss: 0.990, Validation Accuracy: 74.78%
# Epoch 58: Training Loss: 2.016, Training Accuracy: 53.82%, Validation Loss: 0.982, Validation Accuracy: 75.54%
# Epoch 59: Training Loss: 2.041, Training Accuracy: 52.83%, Validation Loss: 1.004, Validation Accuracy: 74.86%
# Epoch 60: Training Loss: 2.051, Training Accuracy: 53.27%, Validation Loss: 0.995, Validation Accuracy: 74.92%
# Epoch 61: Training Loss: 2.061, Training Accuracy: 52.36%, Validation Loss: 0.997, Validation Accuracy: 75.03%
# Epoch 62: Training Loss: 2.016, Training Accuracy: 53.35%, Validation Loss: 1.004, Validation Accuracy: 75.15%
# Epoch 63: Training Loss: 2.028, Training Accuracy: 52.98%, Validation Loss: 1.006, Validation Accuracy: 75.14%
# Epoch 64: Training Loss: 2.012, Training Accuracy: 52.07%, Validation Loss: 1.000, Validation Accuracy: 75.26%
# Epoch 65: Training Loss: 2.058, Training Accuracy: 53.69%, Validation Loss: 1.001, Validation Accuracy: 75.38%
# Epoch 66: Training Loss: 1.995, Training Accuracy: 53.43%, Validation Loss: 1.026, Validation Accuracy: 75.30%
# Epoch 67: Training Loss: 2.024, Training Accuracy: 53.78%, Validation Loss: 0.985, Validation Accuracy: 75.32%
# Epoch 68: Training Loss: 2.019, Training Accuracy: 53.82%, Validation Loss: 1.008, Validation Accuracy: 75.40%
# Epoch 69: Training Loss: 1.990, Training Accuracy: 53.90%, Validation Loss: 0.993, Validation Accuracy: 75.40%
# Epoch 70: Training Loss: 2.033, Training Accuracy: 52.89%, Validation Loss: 0.987, Validation Accuracy: 75.37%
# Epoch 71: Training Loss: 1.961, Training Accuracy: 53.50%, Validation Loss: 0.995, Validation Accuracy: 75.36%
# Epoch 73: Training Loss: 1.936, Training Accuracy: 54.35%, Validation Loss: 0.972, Validation Accuracy: 75.54%
# Epoch 74: Training Loss: 2.050, Training Accuracy: 52.44%, Validation Loss: 0.986, Validation Accuracy: 75.52%
# Epoch 75: Training Loss: 2.049, Training Accuracy: 52.67%, Validation Loss: 0.983, Validation Accuracy: 75.63%
# Epoch 76: Training Loss: 2.039, Training Accuracy: 52.16%, Validation Loss: 0.995, Validation Accuracy: 75.45%
# Epoch 77: Training Loss: 2.058, Training Accuracy: 52.94%, Validation Loss: 0.982, Validation Accuracy: 75.45%
# Epoch 78: Training Loss: 2.039, Training Accuracy: 52.81%, Validation Loss: 0.973, Validation Accuracy: 75.74%
# Epoch 79: Training Loss: 2.033, Training Accuracy: 52.68%, Validation Loss: 0.998, Validation Accuracy: 75.35%
# Epoch 80: Training Loss: 2.040, Training Accuracy: 52.93%, Validation Loss: 0.990, Validation Accuracy: 75.48%
# Epoch 81: Training Loss: 1.999, Training Accuracy: 53.34%, Validation Loss: 1.023, Validation Accuracy: 75.24%
# Epoch 82: Training Loss: 2.020, Training Accuracy: 53.13%, Validation Loss: 0.990, Validation Accuracy: 75.57%
# Epoch 83: Training Loss: 2.029, Training Accuracy: 53.24%, Validation Loss: 0.988, Validation Accuracy: 75.54%
# Epoch 84: Training Loss: 2.022, Training Accuracy: 52.08%, Validation Loss: 0.966, Validation Accuracy: 75.47%
# Epoch 85: Training Loss: 2.024, Training Accuracy: 53.70%, Validation Loss: 1.005, Validation Accuracy: 75.28%
# Epoch 86: Training Loss: 2.067, Training Accuracy: 51.64%, Validation Loss: 0.974, Validation Accuracy: 75.54%
# Epoch 87: Training Loss: 1.927, Training Accuracy: 54.95%, Validation Loss: 1.004, Validation Accuracy: 75.46%
# Epoch 88: Training Loss: 1.981, Training Accuracy: 54.38%, Validation Loss: 0.963, Validation Accuracy: 75.58%
# Epoch 89: Training Loss: 1.922, Training Accuracy: 54.49%, Validation Loss: 0.957, Validation Accuracy: 75.67%
# Epoch 90: Training Loss: 1.954, Training Accuracy: 53.97%, Validation Loss: 0.962, Validation Accuracy: 75.55%
# Epoch 91: Training Loss: 1.930, Training Accuracy: 54.71%, Validation Loss: 0.973, Validation Accuracy: 75.46%
# Epoch 92: Training Loss: 1.957, Training Accuracy: 54.32%, Validation Loss: 0.958, Validation Accuracy: 75.60%
# Epoch 93: Training Loss: 1.977, Training Accuracy: 54.95%, Validation Loss: 0.963, Validation Accuracy: 75.52%
# Epoch 94: Training Loss: 2.005, Training Accuracy: 53.20%, Validation Loss: 0.965, Validation Accuracy: 75.50%
# Epoch 95: Training Loss: 2.070, Training Accuracy: 53.23%, Validation Loss: 0.973, Validation Accuracy: 75.51%
# Epoch 96: Training Loss: 2.015, Training Accuracy: 53.81%, Validation Loss: 0.967, Validation Accuracy: 75.51%
# Epoch 97: Training Loss: 2.011, Training Accuracy: 52.35%, Validation Loss: 0.992, Validation Accuracy: 75.47%
# Epoch 98: Training Loss: 1.992, Training Accuracy: 54.51%, Validation Loss: 0.955, Validation Accuracy: 75.77%
# Epoch 99: Training Loss: 2.031, Training Accuracy: 52.92%, Validation Loss: 0.981, Validation Accuracy: 75.47%
# Epoch 100: Training Loss: 1.938, Training Accuracy: 55.15%, Validation Loss: 0.979, Validation Accuracy: 75.58%
